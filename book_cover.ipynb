# %%
import pandas as pd
from wordcloud import WordCloud
import os

# %%
data = pd.read_csv("data/keywords.csv")

data.head(10)
# Out:
#         Id                                               Name  \
# 0  1100003                                         the prince
# 1  1100004  sermons from duke chapel: voices from "a great...
# 2  1100009                           the idea of a university
# 3  1100010  caring and curing: health and medicine in the ...
# 4  1100013  the alamo remembered: tejano accounts and pers...
# 5  1100020  rousseau: 'the discourses' and other early pol...
# 6  1100021  how not to study judaism, examples and counter...
# 7  1100025  basic research and technologies for two-stage-...
# 8  1100026    between two streams: a diary from bergen-belsen
# 9  1100031  the lived experience of group spiritual direction
#
#                  Authors        ISBN  Rating  PublishYear  \
# 0    niccolò_machiavelli  0226500438    3.82         1998
# 1    william_h._willimon  0822334836    4.29         2005
# 2      john_henry_newman  0300064055    4.12         1996
# ...

# %%
# Create the image directory if it doesn't exist
if not os.path.exists('cover'):
    os.makedirs('cover')

# Initialize a list to store the image paths
data['image_path'] = ''
# Generate and save a word cloud for each of the first 5 entries
for i in range(len(data)):
    keywords_entry = data['keywords'].iloc[i]
    wordcloud = WordCloud(width=400, height=600, background_color='white').generate(keywords_entry)

    # Save the word cloud image
    bookID = data['Id'].iloc[i]
    image_path = os.path.join('cover', f'{bookID}_{i + 1}.png')
    data.at[i, 'image_path'] = image_path
    wordcloud.to_file(image_path)
    print(f"Word cloud image saved to {image_path}")
# Out:
# Word cloud image saved to cover/1100003_1.png
# Word cloud image saved to cover/1100004_2.png
# Word cloud image saved to cover/1100009_3.png
# Word cloud image saved to cover/1100010_4.png
# Word cloud image saved to cover/1100013_5.png
# Word cloud image saved to cover/1100020_6.png
# Word cloud image saved to cover/1100021_7.png
# Word cloud image saved to cover/1100025_8.png
# Word cloud image saved to cover/1100026_9.png
# Word cloud image saved to cover/1100031_10.png
# Word cloud image saved to cover/1100032_11.png
# Word cloud image saved to cover/1100035_12.png
# Word cloud image saved to cover/1100036_13.png
# Word cloud image saved to cover/1100038_14.png
# Word cloud image saved to cover/1100041_15.png
# Word cloud image saved to cover/1100042_16.png
# Word cloud image saved to cover/1100043_17.png
# Word cloud image saved to cover/1100044_18.png
# Word cloud image saved to cover/1100045_19.png
# Word cloud image saved to cover/1100048_20.png
# ...

# %%
# Save the updated DataFrame back to a CSV file
data.to_csv("data/keywords.csv", index=False)
